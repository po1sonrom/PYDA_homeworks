# %% [markdown]
# **Задача1**

# %% [markdown]
# Скачайте с сайта https://grouplens.org/datasets/movielens/ датасет любого размера. Определите какому фильму было выставлено больше всего оценок 5.0.

# %% [markdown]
# ***Решение***

# %%
import pandas as pd

ratings = pd.read_csv('ml-25m/ratings.csv') #загружаем файл с рейтингами

max_rating = ratings['rating'].max() #определяем максимальный рейтинг (5)
filter_for_max_rating = joined[(joined ['rating'] == max_rating)] #объединяем по максимально полученному рейтингу (5)
group_movieid = filter_for_max_rating.groupby(['movieId'])['movieId'].count() #группируем по movieId по подсчитанному максимальному рейтингу

group_movieid.sort_values(ascending = False).head(3) #выводим топ 3 фильмов  по убыванию суммы с максимальным рейтингом
# Out:
# movieId
# 318    39553
# 296    32169
# 356    25918
# Name: movieId, dtype: int64

# %% [markdown]
# **Задание2**

# %% [markdown]
# По данным файла power.csv посчитайте суммарное потребление стран Прибалтики (Латвия, Литва и Эстония) категорий 4, 12 и 21 за период с 2005 по 2010 года. Не учитывайте в расчетах отрицательные значения quantity.

# %% [markdown]
# ***Решение***

# %%
power = pd.read_csv('power.csv')

baltic_countryies = power[(power['country'] == 'Latvia') | (power['country'] == 'Lithuania') | (power['country'] == 'Estonia') ] #берем информацию по Латвии, Литве и Эстонии
fc = baltic_countryies[(baltic_countryies['category'] == 4) | (baltic_countryies['category'] == 12) | (baltic_countryies['category'] == 21) & ( baltic_countryies['year'] < 2010) & (baltic_countryies['year'] > 2005)] #делаем нужную выборку по категориям и годам
fc['quantity'].sum() #считаем подтребление сумарное по столбцу quantity
# Out:
# 165867.0

# %% [markdown]
# ***Задание3***

# %% [markdown]
# Выберите страницу любого сайта с табличными данными. Импортируйте таблицы в pandas dataframe.
# Примеры страниц (необязательно брать именно эти):
# https://fortrader.org/quotes
# https://www.finanz.ru/valyuty/v-realnom-vremeni

# %% [markdown]
# ***Решение***

# %%
pd.read_html('https://www.finam.ru/quotes/indices/')[0]
# Out:
#     Unnamed: 0             Инструмент Посл. сделка % Изм. цены    Открытие  \
# 0          NaN                AMMEKS*      2058.74      -0.71%    2068.900
# 1          NaN    ASX200 (Австралия)*       5927.8      -2.04%    6051.100
# 2          NaN     Bovespa (Бразилия)    102912.24         -2%  105009.990
# 3          NaN     BSE Sensex (Индия)     37606.89      -0.34%   37847.880
# 4          NaN                 CAC 40      4783.69      -1.43%    4866.240
# 5          NaN         CSI200 (Китай)     5342.432       1.51%    5254.212
# 6          NaN         CSI300 (Китай)     4695.046       0.84%    4652.182
# 7          NaN               D&J-Ind*     26433.71       0.44%   26414.710
# 8          NaN            Futsee-100*      5897.76      -1.54%    5989.990
# 9          NaN    Hang Seng (Гонконг)      24657.9      -0.21%   24747.290
# 10         NaN          KOSPI (Корея)      2249.37      -0.78%    2278.530
# ...
