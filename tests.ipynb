# %%
print(99, 'bottles', 'would be enough:', 100)
print('One word ' 'Second')
('letters,one').split(',')[1]
# Out:
# 99 bottles would be enough: 100
# One word Second
# 'one'

# %%
import smtplib as sl
import getpass

smtpObj = sl.SMTP('smtp.gmail.com', 587)
smtpObj.ehlo()
# Out:
# (250,
#  b'smtp.gmail.com at your service, [77.74.28.77]\nSIZE 35882577\n8BITMIME\nSTARTTLS\nENHANCEDSTATUSCODES\nPIPELINING\nCHUNKING\nSMTPUTF8')

# %%
smtpObj.starttls()
# Out:
# (220, b'2.0.0 Ready to start TLS')

# %%
pass_ = getpass.getpass('Пароль: ')
smtpObj.login('philipp.rodchenkov@primapower.com', pass_)
# Out:
# Пароль: ········
# ---------------------------------------------------------------------------
# SMTPNotSupportedError                     Traceback (most recent call last)
# <ipython-input-4-3ecf95c6fabb> in <module>
#       1 pass_ = getpass.getpass('Пароль: ')
# ----> 2 smtpObj.login('philipp.rodchenkov@primapower.com', pass_)
#
# ~\anaconda3\lib\smtplib.py in login(self, user, password, initial_response_ok)
#     695         if not self.has_extn("auth"):
#     696             raise SMTPNotSupportedError(
# --> 697                 "SMTP AUTH extension not supported by server.")
#     698
#     699         # Authentication methods the server claims to support
#
# SMTPNotSupportedError: SMTP AUTH extension not supported by server.
