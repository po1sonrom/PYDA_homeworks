# %% [markdown]
# **Задание 1**. Дан список с визитами по городам и странам.
# Напишите код, который возвращает отфильтрованный список geo_logs, содержащий только визиты из России.

# %%
geo_logs = [
    {'visit1': ['Москва', 'Россия']},
    {'visit2': ['Дели', 'Индия']},
    {'visit3': ['Владимир', 'Россия']},
    {'visit4': ['Лиссабон', 'Португалия']},
    {'visit5': ['Париж', 'Франция']},
    {'visit6': ['Лиссабон', 'Португалия']},
    {'visit7': ['Тула', 'Россия']},
    {'visit8': ['Тула', 'Россия']},
    {'visit9': ['Курск', 'Россия']},
    {'visit10': ['Архангельск', 'Россия']}
]

# %% [markdown]
# **Решение**

# %%
for all_visits in geo_logs:
    if list(all_visits.values())[0][1] == 'Россия':
            print(list(all_visits.keys())[0])
# Out:
# visit1
# visit3
# visit7
# visit8
# visit9
# visit10

# %% [markdown]
# **Задание 2**. Выведите на экран все уникальные гео-ID из значений словаря ids. Т. е. список вида [213, 15, 54, 119, 98, 35]

# %%
ids = {'user1': [213, 213, 213, 15, 213], 
       'user2': [54, 54, 119, 119, 119], 
       'user3': [213, 98, 98, 35]}

# %% [markdown]
# **Решение**

# %%
geo_id = ids.values()
new_numbers = []
for geo_id in geo_id:
    for numbers in geo_id:
        new_numbers.append(numbers)
print(set(new_numbers))
# Out:
# {98, 35, 15, 213, 54, 119}

# %% [markdown]
# **Задание 3**. Дан список поисковых запросов. Получить распределение количества слов в них.
# Т. е. поисковых запросов из одного - слова 5%, из двух - 7%, из трех - 3% и т.д.

# %%
queries = [
    'смотреть сериалы онлайн',
    'новости спорта',
    'афиша кино',
    'курс доллара',
    'сериалы этим летом',
    'курс по питону',
    'сериалы про спорт',
]

# %% [markdown]
# **Решение**

# %%
list_ = []
sum_ = 0

for words_qnty in queries:
    list_.append(len(words_qnty.split()))

dic = {}.fromkeys(list_, 0)
for a in list_:
    dic[a] += 1

for count in dic.values():
    sum_ += count
    
for result_by_word in dic:
    print('Поисковых запросов из ', result_by_word, ' слов(а):', round((dic[result_by_word] / sum_)*100, 2), '%')
# Out:
# Поисковых запросов из  3  слов(а): 57.14 %
# Поисковых запросов из  2  слов(а): 42.86 %

# %%
sum_1_word = 0
sum_2_words = 0
sum_3_words = 0

for words_qnty in queries:
    if len(words_qnty.split()) == 1:
        sum_1_word += 1
    elif len(words_qnty.split()) == 2:
        sum_2_words += 1
    else:
        sum_3_words += 1

total_summ = sum_1_word + sum_2_words + sum_3_words
        
print('Поисковых запросов из одного слова: ', round((sum_1_word / total_summ)*100, 2), '%')
print('Поисковых запросов из двух слов: ', round((sum_2_words / total_summ)*100, 2), '%')
print('Поисковых запросов из трех слов: ', round((sum_3_words / total_summ)*100, 2), '%')
# Out:
# Поисковых запросов из одного слова:  0.0 %
# Поисковых запросов из двух слов:  42.86 %
# Поисковых запросов из трех слов:  57.14 %

# %% [markdown]
# **Задание 4**. Дана статистика рекламных каналов по объемам продаж. Напишите скрипт, который возвращает название канала с максимальным объемом.
# Т. е. в данном примере скрипт должен возвращать 'yandex'.

# %%
stats = {'facebook': 55, 'yandex': 120, 'vk': 115, 'google': 300, 'email': 42, 'ok': 98}

# %% [markdown]
# **Решение**

# %%
print(max(stats, key = stats.get))
# Out:
# google

# %% [markdown]
# **Задание 5**. Напишите код для преобразования произвольного списка вида ['2018-01-01', 'yandex', 'cpc', 100] (он может быть любой длины) в словарь {'2018-01-01': {'yandex': {'cpc': 100}}}

# %% [markdown]
# **Решение**

# %%
list_ = ['2018-01-01', 'yandex', 'cpc', 100]

list_.reverse()
param = 0
new_dic = {}

for i in range (1, len(list_)):
    if param == 0:
        new_dic[list_[i]]= list_[i-1]
        param = 1
    else:
        new_dic = {list_[i]: new_dic}

print(new_dic)
# Out:
# {'2018-01-01': {'yandex': {'cpc': 100}}}
